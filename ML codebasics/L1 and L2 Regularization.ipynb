# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(r'C:\Users\BASHA\Desktop\machine learning\Melbourne_housing_FULL.csv')
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
dataset.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
dataset.shape
# Out:
# (34857, 21)

# %%
cols_to_use = ['Suburb','Rooms','Type','Method','SellerG','Distance','Bathroom','Car','Bedroom2','Landsize','BuildingArea','CouncilArea','Regionname','Propertycount']

dataset = dataset[cols_to_use]
dataset.head()
# Out:
#        Suburb  Rooms Type Method SellerG  Distance  Bathroom  Car  Bedroom2  \
# 0  Abbotsford      2    h     SS  Jellis       2.5       1.0  1.0       2.0
# 1  Abbotsford      2    h      S  Biggin       2.5       1.0  1.0       2.0
# 2  Abbotsford      2    h      S  Biggin       2.5       1.0  0.0       2.0
# 3  Abbotsford      3    u     VB  Rounds       2.5       2.0  1.0       3.0
# 4  Abbotsford      3    h     SP  Biggin       2.5       2.0  0.0       3.0
#
#    Landsize  BuildingArea         CouncilArea             Regionname  \
# 0     126.0           NaN  Yarra City Council  Northern Metropolitan
# 1     202.0           NaN  Yarra City Council  Northern Metropolitan
# 2     156.0          79.0  Yarra City Council  Northern Metropolitan
# 3       0.0           NaN  Yarra City Council  Northern Metropolitan
# 4     134.0         150.0  Yarra City Council  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# 3         4019.0
# ...

# %%
dataset.shape
# Out:
# (34857, 14)

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Distance             1
# Bathroom          8226
# Car               8728
# Bedroom2          8217
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
cols_to_fill_zero = ['Propertycount','Distance','Bedroom2','Bathroom','Car']
dataset[cols_to_fill_zero] = dataset[cols_to_fill_zero].fillna(0)
dataset.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Distance             0
# Bathroom             0
# Car                  0
# Bedroom2             0
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
dataset['Landsize'] = dataset['Landsize'].fillna(dataset.Landsize.mean())
dataset['BuildingArea'] = dataset['BuildingArea'].fillna(dataset.BuildingArea.mean())
dataset.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Distance         0
# Bathroom         0
# Car              0
# Bedroom2         0
# Landsize         0
# BuildingArea     0
# CouncilArea      3
# Regionname       3
# Propertycount    0
# dtype: int64

# %%
dataset.dropna(inplace=True)
dataset.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Distance         0
# Bathroom         0
# Car              0
# Bedroom2         0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset_int = dataset.astype(int)
dataset_int.head()
# Out:
#    Rooms  Distance  Bathroom  Car  Bedroom2  Landsize  BuildingArea  \
# 0      2         2         1    1         2       126           160
# 1      2         2         1    1         2       202           160
# 2      2         2         1    0         2       156            79
# 3      3         2         2    1         3         0           160
# 4      3         2         2    0         3       134           150
#
#    Propertycount  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# 0           4019                  0                    0  ...
# 1           4019                  0                    0  ...
# 2           4019                  0                    0  ...
# 3           4019                  0                    0  ...
# 4           4019                  0                    0  ...
#
#    CouncilArea_Wyndham City Council  CouncilArea_Yarra City Council  \
# 0                                 0                               1
# ...

# %%
X = dataset
y = dataset.Price.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17120\3157775108.py in ?()
#       1 X = dataset
# ----> 2 y = dataset.Price.dropna(inplace=True)
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Price'
